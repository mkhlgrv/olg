# %%
import pandas as pd
from scipy.optimize import fsolve
import numpy as np
import itertools
import copy
from cyipopt import minimize_ipopt
import warnings
import matplotlib.pyplot as plt
from jax.config import config
# Enable 64 bit floating point precision
config.update("jax_enable_x64", True)

# We use the CPU instead of GPU und mute all warnings if no GPU/TPU is found.
config.update('jax_platform_name', 'cpu')

# import jax.numpy as np
from jax import jit, grad, jacfwd, jacrev
from tqdm.contrib.telegram import tqdm, trange
from dotenv import load_dotenv
import os

from bob_telegram_tools.bot import TelegramBot
load_dotenv()
import pyreadr
import numpy as np
import pickle
import pandas as pd
import statsmodels.api as sm
bot = TelegramBot(os.getenv('comp_bot_token'),
                      os.getenv('chat_id'))

from olg import *

olg = OLG_model(G=60,T=300,N=N,epsilon=epsilon, rho=rho_reform,
                gov_ratio=0.2,gov_const=gov_const,
                sigma = sigma,Pi=Pi,r = r,price_M =price_M,
                price_E=price_E, tau_I=tau_I,tau_II=tau_II,tau_Ins=tau_Ins,
                tau_pi=tau_pi, tau_VA=tau_VA, tau_rho=tau_rho, beta = 0.99,
                theta =1,
                phi =0.23, # цель 38 миллионов в стеди стейт или 65% в начальном положении
                psi = 24.
                , omega=0.269
                , alpha = 0.35, delta=0.0608,
                A=A,initial=initial, Oil=Oil,eta =0.25,steady_max_iter=5000,max_iter=5000,
                steady_guess=steady_guess)


with open('olg_base_with_assets.file', 'rb') as f:
    olg_old=pickle.load(f)
# olg_old.sigma[:] = 0.3
olg.k, olg.l, olg.c,\
olg.a, olg.steady, olg.L_share,\
olg.L, olg.L, olg.i, olg.I, olg.lmbda,\
olg.lmbda_to_price, olg.price, olg.price,\
olg.price_N, olg.sigma, olg.w = olg_old.k, olg_old.l, olg_old.c,\
olg_old.a, olg_old.steady, olg_old.L_share,\
olg_old.L, olg_old.L, olg_old.i, olg_old.I, olg_old.lmbda,\
olg_old.lmbda_to_price, olg_old.price, olg_old.price,\
olg_old.price_N, olg_old.sigma, olg_old.w

olg.steady_state()

olg.steady_state()
olg.update_a_initial()

olg.create_guess(249,300)

for t in range(1, olg.T):
    olg.update_household(t)

olg.T = 300
niter=2
i=1
fig, ax = plt.subplots(3,3, figsize = (16,16))       
ax[0,0].plot(olg.k[0,:(olg.T+50)], alpha = (i+1)/niter, color="black", label = r"$k_N$")
ax[0,0].plot(olg.k[1,:(olg.T+50)], alpha = (i+1)/niter, color="red", label = r"$k_N$")
ax[0,1].plot(olg.Consumption[:(olg.T+50)], alpha = (i+1)/niter, color="black", label = r"$C$")
ax[0,2].plot(olg.Labor[:(olg.T+50)], alpha = (i+1)/niter, color="black", label = r"$L$")
ax[1,0].plot(olg.w[:(olg.T+50)], alpha = (i+1)/niter, color="black", label = r"$w$")
ax[1,1].plot(olg.price[:(olg.T+50)], alpha = (i+1)/niter, color="red", label = r"$p$")
ax[1,2].plot(olg.price[:(olg.T+50)], alpha = (i+1)/niter, color="blue", label = r"$p_N$")
ax[2,0].plot(olg.c[0,:,1:(olg.T)].diagonal(-olg.G+1), alpha = (i+1)/niter, color="black", label = r"$c_{f}$")
ax[2,0].plot(olg.c[1,:,1:(olg.T)].diagonal(-olg.G+1), alpha = (i+1)/niter, color="red", label = r"$c_{f}$")
ax[2,1].plot(olg.l[0,:,1:(olg.T)].diagonal(-olg.G+1), alpha = (i+1)/niter, color="black", label = r"$l_{f}$")
ax[2,1].plot(olg.l[1,:,1:(olg.T)].diagonal(-olg.G+1), alpha = (i+1)/niter, color="red", label = r"$l_{m}$")
ax[2,2].plot(olg.a[0,:,1:(olg.T)].diagonal(-olg.G+1), alpha = (i+1)/niter, color="black", label = r"$a_{f}$")
ax[2,2].plot(olg.a[1,:,1:(olg.T)].diagonal(-olg.G+1), alpha = (i+1)/niter, color="red", label = r"$a_{m}$")
for row in ax:
    for col in row:
        col.legend()
msg = bot.send_plot(fig)
bot.clean_tmp_dir()
# Out:
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************

# %%
name = 'reform'
t_0 = 6
niter = 50
for i in range(niter):
    for t in range(t_0,olg.T):
        olg.update_government(t)
    for t in range(t_0, olg.T):
        olg.update_household(t)
    for t in tqdm(reversed(range(t_0,olg.T)),
                      desc = f'{name} path to steady {i}',
                      total=olg.T-1,
                          token=os.getenv('comp_bot_token'),
                          chat_id=os.getenv('chat_id')):

        olg.update_guess(t)
        
    fig, ax = plt.subplots(3,3, figsize = (16,16))       
    ax[0,0].plot(olg.k[0,:(olg.T+50)], alpha = (i+1)/niter, color="black", label = r"$k_N$")
    ax[0,0].plot(olg.k[1,:(olg.T+50)], alpha = (i+1)/niter, color="red", label = r"$k_N$")
    ax[0,1].plot(olg.Consumption[:(olg.T+50)], alpha = (i+1)/niter, color="black", label = r"$C$")
    ax[0,2].plot(olg.Labor[:(olg.T+50)], alpha = (i+1)/niter, color="black", label = r"$L$")
    ax[1,0].plot(olg.w[:(olg.T+50)], alpha = (i+1)/niter, color="black", label = r"$w$")
    ax[1,1].plot(olg.price[:(olg.T+50)], alpha = (i+1)/niter, color="red", label = r"$p$")
    ax[1,2].plot(olg.price[:(olg.T+50)], alpha = (i+1)/niter, color="blue", label = r"$p_N$")
    ax[2,0].plot(olg.c[0,:,1:(olg.T)].diagonal(-olg.G+1), alpha = (i+1)/niter, color="black", label = r"$c_{f}$")
    ax[2,0].plot(olg.c[1,:,1:(olg.T)].diagonal(-olg.G+1), alpha = (i+1)/niter, color="red", label = r"$c_{f}$")
    ax[2,1].plot(olg.l[0,:,1:(olg.T)].diagonal(-olg.G+1), alpha = (i+1)/niter, color="black", label = r"$l_{f}$")
    ax[2,1].plot(olg.l[1,:,1:(olg.T)].diagonal(-olg.G+1), alpha = (i+1)/niter, color="red", label = r"$l_{m}$")
    ax[2,2].plot(olg.a[0,:,1:(olg.T)].diagonal(-olg.G+1), alpha = (i+1)/niter, color="black", label = r"$a_{f}$")
    ax[2,2].plot(olg.a[1,:,1:(olg.T)].diagonal(-olg.G+1), alpha = (i+1)/niter, color="red", label = r"$a_{m}$")
    bot.update_plot(msg, fig)
    with open(f'olg_{name}.file', 'wb') as f:
        pickle.dump(olg, f,protocol = pickle.HIGHEST_PROTOCOL)

#     price_update = np.array([item[-1]['x'][-1] for key, item in olg.history.items() if len(item)!=0])
#     error = abs(0.5*(olg.price[1:(olg.T)]-price_update)/(olg.price[1:(olg.T)]+price_update))
#     print(error)
#     if max(error) < tol/10:
#         break
bot.clean_tmp_dir()
# Out:
# reform path to steady 0:   0%|          | 0/299 [00:00<?, ?it/s]
# reform path to steady 1:   0%|          | 0/299 [00:00<?, ?it/s]
# reform path to steady 2:   0%|          | 0/299 [00:00<?, ?it/s]
# reform path to steady 3:   0%|          | 0/299 [00:00<?, ?it/s]
# reform path to steady 4:   0%|          | 0/299 [00:00<?, ?it/s]
# reform path to steady 5:   0%|          | 0/299 [00:00<?, ?it/s]
# reform path to steady 6:   0%|          | 0/299 [00:00<?, ?it/s]
# reform path to steady 7:   0%|          | 0/299 [00:00<?, ?it/s]
# reform path to steady 8:   0%|          | 0/299 [00:00<?, ?it/s]
# reform path to steady 9:   0%|          | 0/299 [00:00<?, ?it/s]
# reform path to steady 10:   0%|          | 0/299 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [3], in <cell line: 4>()
#       8     olg.update_household(t)
#       9 for t in tqdm(reversed(range(t_0,olg.T)),
#      10                   desc = f'{name} path to steady {i}',
#      11                   total=olg.T-1,
#      12                       token=os.getenv('comp_bot_token'),
#      13                       chat_id=os.getenv('chat_id')):
# ---> 15     olg.update_guess(t)
#      17 fig, ax = plt.subplots(3,3, figsize = (16,16))
#      18 ax[0,0].plot(olg.k[0,:(olg.T+50)], alpha = (i+1)/niter, color="black", label = r"$k_N$")
#
# File ~/science/olg/olg.py:622, in OLG_model.update_guess(self, t, t_0)
#     619 obj_hess = jit(jacrev(jacfwd(obj_jit)))
#     621 tol = 1e-5
# --> 622 result = minimize_ipopt(obj_jit, jac=obj_grad, hess=obj_hess, x0=z_guess
#     623                     , options = {"max_iter":self.max_iter, "print_level":0,
#     624                                  "check_derivatives_for_naninf":"yes"}
#     625                     , tol=tol)
#     626 if result["success"] and result['fun']<tol:
#     627     self.i[0,t],self.k[0,t+1],self.L_share[0,t],\
#     628     self.lmbda_to_price[0,t], self.i[1,t],self.k[1,t+1],\
#     629     self.lmbda_to_price[1,t],\
#     630     self.w[t], self.price_N[t], self.price[t] = self.eta*result["x"] + (1-self.eta)*z_guess
#
# File ~/anaconda3/envs/olg/lib/python3.8/site-packages/cyipopt/scipy_interface.py:311, in minimize_ipopt(fun, x0, args, kwargs, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     308         msg = 'Invalid option for IPOPT: {0}: {1} (Original message: "{2}")'
#     309         raise TypeError(msg.format(option, value, e))
# --> 311 x, info = nlp.solve(_x0)
#     313 if np.asarray(x0).shape == ():
#     314     x = x[0]
#
# File ~/anaconda3/envs/olg/lib/python3.8/site-packages/cyipopt/cython/ipopt_wrapper.pyx:642, in ipopt_wrapper.Problem.solve()
#
# File ~/anaconda3/envs/olg/lib/python3.8/site-packages/cyipopt/cython/ipopt_wrapper.pyx:895, in ipopt_wrapper.hessian_cb()
#
# File ~/anaconda3/envs/olg/lib/python3.8/site-packages/cyipopt/scipy_interface.py:161, in IpoptProblemWrapper.hessian(self, x, lagrange, obj_factor)
#     160 def hessian(self, x, lagrange, obj_factor):
# --> 161     H = obj_factor * self.obj_hess(x)  # type: ignore
#     162     # split the lagrangian multipliers for each constraint hessian
#     163     lagrs = np.split(lagrange, np.cumsum(self._constraint_dims[:-1]))
#
#     [... skipping hidden 1 frame]
#
# File ~/anaconda3/envs/olg/lib/python3.8/site-packages/jax/_src/api.py:473, in _cpp_jit.<locals>.cache_miss(*args, **kwargs)
#     471   in_type = pe.infer_lambda_input_type(None, args_flat)
#     472   flat_fun = lu.annotate(flat_fun, in_type)
# --> 473 out_flat = xla.xla_call(
#     474     flat_fun, *args_flat,
#     475     device=device, backend=backend, name=flat_fun.__name__,
#     476     donated_invars=donated_invars, inline=inline, keep_unused=keep_unused)
#     477 out_pytree_def = out_tree()
#     478 out = tree_unflatten(out_pytree_def, out_flat)
#
# File ~/anaconda3/envs/olg/lib/python3.8/site-packages/jax/core.py:1767, in CallPrimitive.bind(self, fun, *args, **params)
#    1766 def bind(self, fun, *args, **params):
# -> 1767   return call_bind(self, fun, *args, **params)
#
# File ~/anaconda3/envs/olg/lib/python3.8/site-packages/jax/core.py:1783, in call_bind(primitive, fun, *args, **params)
#    1781 tracers = map(top_trace.full_raise, args)
#    1782 fun_ = lu.annotate(fun_, fun.in_type)
# -> 1783 outs = top_trace.process_call(primitive, fun_, tracers, params)
#    1784 return map(full_lower, apply_todos(env_trace_todo(), outs))
#
# File ~/anaconda3/envs/olg/lib/python3.8/site-packages/jax/core.py:680, in EvalTrace.process_call(self, primitive, f, tracers, params)
#     679 def process_call(self, primitive, f, tracers, params):
# --> 680   return primitive.impl(f, *tracers, **params)
#
# File ~/anaconda3/envs/olg/lib/python3.8/site-packages/jax/_src/dispatch.py:182, in _xla_call_impl(***failed resolving arguments***)
#     180 if fun.in_type is not None:
#     181   arg_specs = [(None, *xs) for _, *xs in arg_specs]
# --> 182 compiled_fun = _xla_callable(fun, device, backend, name, donated_invars,
#     183                              keep_unused, *arg_specs)
#     184 try:
#     185   return compiled_fun(*args)
#
# File ~/anaconda3/envs/olg/lib/python3.8/site-packages/jax/linear_util.py:285, in cache.<locals>.memoized_fun(fun, *args)
#     283   fun.populate_stores(stores)
#     284 else:
# --> 285   ans = call(fun, *args)
#     286   cache[key] = (ans, fun.stores)
#     288 thread_local.most_recent_entry = weakref.ref(ans)
#
# File ~/anaconda3/envs/olg/lib/python3.8/site-packages/jax/_src/dispatch.py:230, in _xla_callable_uncached(fun, device, backend, name, donated_invars, keep_unused, *arg_specs)
#     228 def _xla_callable_uncached(fun: lu.WrappedFun, device, backend, name,
#     229                            donated_invars, keep_unused, *arg_specs):
# --> 230   return lower_xla_callable(fun, device, backend, name, donated_invars, False,
#     231                             keep_unused, *arg_specs).compile().unsafe_call
#
# File ~/anaconda3/envs/olg/lib/python3.8/site-packages/jax/_src/dispatch.py:704, in XlaComputation.compile(self)
#     701     self._executable = XlaCompiledComputation.from_trivial_jaxpr(
#     702         **self.compile_args)
#     703   else:
# --> 704     self._executable = XlaCompiledComputation.from_xla_computation(
#     705         self.name, self._hlo, self._explicit_args, **self.compile_args)
#     707 return self._executable
#
# File ~/anaconda3/envs/olg/lib/python3.8/site-packages/jax/_src/dispatch.py:806, in XlaCompiledComputation.from_xla_computation(name, xla_computation, explicit_args, nreps, device, backend, tuple_args, in_avals, out_avals, effects, kept_var_idx, keepalive)
#     803 options.parameter_is_tupled_arguments = tuple_args
#     804 with log_elapsed_time(f"Finished XLA compilation of {name} "
#     805                       "in {elapsed_time} sec"):
# --> 806   compiled = compile_or_get_cached(backend, xla_computation, options)
#     807 buffer_counts = (None if len(out_avals) == 1 and not config.jax_dynamic_shapes
#     808                  else [aval_to_num_buffers(aval) for aval in out_avals])
#     809 if effects:
#
# File ~/anaconda3/envs/olg/lib/python3.8/site-packages/jax/_src/dispatch.py:768, in compile_or_get_cached(backend, computation, compile_options)
#     766     ir_str = computation
#     767   _dump_ir_to_file(module_name, ir_str)
# --> 768 return backend_compile(backend, computation, compile_options)
#
# File ~/anaconda3/envs/olg/lib/python3.8/site-packages/jax/_src/profiler.py:206, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     203 @wraps(func)
#     204 def wrapper(*args, **kwargs):
#     205   with TraceAnnotation(name, **decorator_kwargs):
# --> 206     return func(*args, **kwargs)
#     207   return wrapper
#
# File ~/anaconda3/envs/olg/lib/python3.8/site-packages/jax/_src/dispatch.py:713, in backend_compile(backend, built_c, options)
#     709 @profiler.annotate_function
#     710 def backend_compile(backend, built_c, options):
#     711   # we use a separate function call to ensure that XLA compilation appears
#     712   # separately in Python profiling results
# --> 713   return backend.compile(built_c, compile_options=options)
#
# KeyboardInterrupt:

# %%
ax[0,0].plot(olg_reform.k[0,2:(olg_reform.T)], alpha = (i+1)/niter, color="black", label = r"$k_N$")
ax[0,0].plot(olg_reform.k[1,2:(olg_reform.T)], alpha = (i+1)/niter, color="red", label = r"$k_N$")
ax[0,1].plot(olg_reform.Consumption[2:(olg_reform.T)], alpha = (i+1)/niter, color="black", label = r"$C$")
ax[0,2].plot(olg_reform.Labor[2:(olg_reform.T)], alpha = (i+1)/niter, color="black", label = r"$L$")
ax[1,0].plot(olg_reform.w[2:(olg_reform.T)], alpha = (i+1)/niter, color="black", label = r"$w$")
ax[1,1].plot(olg_reform.price[2:(olg_reform.T)], alpha = (i+1)/niter, color="red", label = r"$p$")
ax[1,2].plot(olg_reform.price[2:(olg_reform.T)], alpha = (i+1)/niter, color="blue", label = r"$p_N$")
ax[2,0].plot(olg_reform.c[0,:,2:(olg_reform.T)].diagonal(-olg_reform.G+1), alpha = (i+1)/niter, color="black", label = r"$c_{f}$")
ax[2,0].plot(olg_reform.c[1,:,2:(olg_reform.T)].diagonal(-olg_reform.G+1), alpha = (i+1)/niter, color="red", label = r"$c_{f}$")
ax[2,1].plot(olg_reform.l[0,:,2:(olg_reform.T)].diagonal(-olg_reform.G+1), alpha = (i+1)/niter, color="black", label = r"$l_{f}$")
ax[2,1].plot(olg_reform.l[1,:,2:(olg_reform.T)].diagonal(-olg_reform.G+1), alpha = (i+1)/niter, color="red", label = r"$l_{m}$")
ax[2,2].plot(olg_reform.a[0,:,2:(olg_reform.T)].diagonal(-olg_reform.G+1), alpha = (i+1)/niter, color="black", label = r"$a_{f}$")
ax[2,2].plot(olg_reform.a[1,:,2:(olg_reform.T)].diagonal(-olg_reform.G+1), alpha = (i+1)/niter, color="red", label = r"$a_{m}$")
